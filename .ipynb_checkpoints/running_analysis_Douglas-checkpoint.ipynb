# %% [markdown]
# ### **Controle de Cardio - Exercícios de Running Douglas (Smart FIT)**
#
# Neste notebook irei registrar os dados obtidos nos exercícios que realizo na academia SmartFit, para controle e análises diversas.
#
# Dt. Início --> 04/04/2024 - Quinta-feira

# %%
import pandas as pd

# 04/04/2024
dados_exercicio = {
    'Data': pd.to_datetime(['04/04/2024']),
    'Distancia (km)': [2.1],
    'Tempo (minutos)': [20],
    'Velocidade media (km/h)': [6.3],
    'Velocidade maxima (km/h)': [8.5],
    'Ritmo medio (min/km)': [9.31],
    'Ritmo maximo (min/km)': [7.03],
    'Calorias queimadas': [148.8],
    'Condicoes climaticas': ['Ensolarado'],    
    'Tipo de terreno': ['Esteira'],
    'Freq cardiaca media': [41],
    'Freq cardiaca maxima': [41],
    'Nivel de esforço': [6],    
    'Companhia': ['Sozinho'],
    'Nivel de cansaço pos-exercicio': [6]
}

# Criando o DataFrame
df = pd.DataFrame(dados_exercicio)

# Exibindo o DataFrame
df
# Out:
#         Data  Distancia (km)  Tempo (minutos)  Velocidade media (km/h)  \
# 0 2024-04-04             2.1               20                      6.3
#
#    Velocidade maxima (km/h)  Ritmo medio (min/km)  Ritmo maximo (min/km)  \
# 0                       8.5                  9.31                   7.03
#
#    Calorias queimadas Condicoes climaticas Tipo de terreno  \
# 0               148.8           Ensolarado         Esteira
#
#    Freq cardiaca media  Freq cardiaca maxima  Nivel de esforço Companhia  \
# 0                   41                    41                 6   Sozinho
#
#    Nivel de cansaço pos-exercicio
# 0                               6

# %%
'''
# 05/04/2024

dados_exercicio = {
    'Data': pd.to_datetime(['05/04/2024']),
    'Distancia (km)': [],
    'Tempo (minutos)': [],
    'Velocidade media (km/h)': [],
    'Velocidade maxima (km/h)': [],
    'Ritmo medio (min/km)': [],
    'Ritmo maximo (min/km)': [],
    'Calorias queimadas': [],
    'Condicoes climaticas': [''],    
    'Tipo de terreno': [''],
    'Freq cardiaca media': [],
    'Freq cardiaca maxima': [],
    'Nivel de esforço': [],    
    'Companhia': ['Sozinho'],
    'Nivel de cansaço pos-exercicio': []
}

novo_df = pd.DataFrame(dados_exercicio)
df = pd.concat([df, novo_df], ignore_index=True)

df
'''
